# %% [markdown]
# ## numpy 简介
# numpy提供了一种高维数组。提供了数据分析的运算基础。
# - numpy是一个有序的，相同数据类型的集合；
#
# ```python
# np.__version__   # 查看python的版本
#
# array1 = np.array([1, 3.14, 'Hello'])
# ```
#
# ## 常见函数

# %%
import numpy as np
import pandas as pd

print(np.__version__)
array1 = np.array([1, 3.14, 'Hello'])
print(type(array1), array1)
# Out:
# 2.2.3
# <class 'numpy.ndarray'> ['1' '3.14' 'Hello']

# %%
name = ["tom", "lucy", "jack"]
np.array()
